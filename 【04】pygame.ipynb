# %%
# 1. 安装 Pygame

conda activate mnist
pip install pygame # 安装在mnist虚拟环境中

# 安装完成后，可以通过以下命令检查是否安装成功：
python -m pygame.examples.aliens

# Pygame的坐标原点（0，0）点位于左上角，X轴自左向右，Y轴自上向下，单位为像素

# %%
# 2. 创建一个简单的 Pygame 窗口

# 导入pygame模块
import pygame

# 初始化 Pygame
pygame.init()

# 设置窗口尺寸
window_size = (600, 640)
screen = pygame.display.set_mode(window_size)

# 设置窗口标题
pygame.display.set_caption("My First Pygame Window")

# 主循环标志
running = True

# 主循环
while running:
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False

# 退出 Pygame
pygame.quit()

# %%
# 3. 绘制图形

# Pygame 使用 RGB 颜色值来设置颜色。以下是一些常见颜色的定义：

WHITE = (255, 255, 255)
BLACK = (0, 0, 0)
RED = (255, 0, 0)
GREEN = (0, 255, 0)
BLUE = (0, 0, 255)

# 绘制矩形
# 我们可以使用 pygame.draw.rect 来绘制矩形：
# 参数说明: screen 指定矩形绘制在哪个屏幕对象上  RED指定颜色 （100,100,50,50）：（left,top,width,height）指定矩形的范围
pygame.draw.rect(screen, RED, (100, 100, 50, 50))

# 我们可以使用 pygame.draw.circle 来绘制圆形：
pygame.draw.circle(screen, BLUE, (200, 200), 30)

# 绘制完图形后，需要更新屏幕以显示图形：
pygame.display.flip()


# pygame的两个重要类型
# pygame.Surface绘图层，或绘图平面，或图层
# • 用于表示图形、文字或图像的绘制效果
# • 与当前屏幕主图层可以并列存在
# • 如果不绘制在主图层上，则不会被显示

# Pygame.Rect 矩形区域
# • 对应于当前主图层的某个具体区域
# • 相当于某个矩形区域的指针或标识信息
# • 可以指定图层绘制在某个矩形区域中
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[3], line 14
#       9 BLUE = (0, 0, 255)
#      11 # 绘制矩形
#      12 # 我们可以使用 pygame.draw.rect 来绘制矩形：
#      13 # 参数说明: screen 指定矩形绘制在哪个屏幕对象上  RED指定颜色 （100,100,50,50）：（left,top,width,height）指定矩形的范围
# ---> 14 pygame.draw.rect(screen, RED, (100, 100, 50, 50))
#      16 # 我们可以使用 pygame.draw.circle 来绘制圆形：
#      17 pygame.draw.circle(screen, BLUE, (200, 200), 30)
#
# error: display Surface quit

# %%
# 显示文字
# 要在 Pygame 窗口上显示文本，我们需要先获取一个 font 字体对象，借助于定义在 pygame.font 模块中的 SysFont() 函数。
# pygame.font.SysFont(字体类型，字体大小)
font = pygame.font.SysFont("宋体", 36)
# font.render(显示的内容，是否开启抗锯齿（布尔值），字体颜色，字体背景颜色)
text = font.render(time_str, True, BLACK, BLUE)
# screen.blit(绘制的文本内容，显示的坐标)
screen.blit(text, (WINDOW_WIDTH - text.get_width() - 10, 10))

# %%
# 运行这段代码，你会看到一个窗口，里面绘制了一个红色的矩形和一个蓝色的圆形。

import pygame
# 初始化 Pygame
pygame.init()
# 设置窗口尺寸
window_size = (480, 640)
screen = pygame.display.set_mode(window_size)
# 设置窗口标题
pygame.display.set_caption("Drawing Shapes")
# 定义颜色
WHITE = (255, 255, 255)
RED = (255, 0, 0)
BLUE = (0, 0, 255)
# 主循环标志
running = True
# 主循环
while running:
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False

    # 填充背景色
    screen.fill(WHITE)
    # 绘制矩形
    pygame.draw.rect(screen, RED, (100, 100, 50, 50))
    # 绘制圆形
    pygame.draw.circle(screen, BLUE, (200, 200), 30)
    # 绘制文字
    text = pygame.font.SysFont("SimHei", 60)  # 创建一个font文本对象
    text_font = text.render("飞机大战", 1, RED, BLUE)  # 渲染文本对象
    screen.blit(text_font, (100,20))  # 绘制文本内容
    # 更新屏幕
    pygame.display.flip()
# 退出 Pygame
pygame.quit()

# %%
# 4. 加载和显示图像

# 加载图像
# 在游戏开发中，经常需要加载和显示图像。Pygame 提供了简单的接口来加载图像。首先，确保你有一个图像文件（例如 player.png）保存在你的项目目录中。
# 使用 pygame.image.load 函数加载图像：
player_image = pygame.image.load('resources/car3.png')

# 显示图像
# 加载图像后，可以使用 blit 方法将图像绘制到屏幕上：
screen.blit(player_image, (100, 100))

# %%
# 添加加载和显示图像功能的完整代码，
# 运行这段代码，你会看到一个窗口，里面显示了加载的图像。

import pygame

# 初始化 Pygame
pygame.init()

# 设置窗口尺寸
window_size = (480, 640)
screen = pygame.display.set_mode(window_size)

# 设置窗口标题
pygame.display.set_caption("Display Image")

# 加载图像
player_image = pygame.image.load('resources/car3.png')

# 主循环标志
running = True

# 主循环
while running:
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False

    # 填充背景色
    screen.fill((255, 255, 255))

    # 显示图像
    screen.blit(player_image, (100, 100))

    # 更新屏幕
    pygame.display.flip()

# 退出 Pygame
pygame.quit()

# %%
# 5. 处理用户输入

# 处理键盘输入
# Pygame 提供了简单的接口来处理键盘输入。你可以在主循环中检测按键事件：

for event in pygame.event.get():  # 捕获事件
    if event.type == pygame.QUIT:  # 判断按键类型
        running = False
    elif event.type == pygame.KEYDOWN:
        if event.key == pygame.K_LEFT:
            print("Left arrow key pressed")
        elif event.key == pygame.K_RIGHT:
            print("Right arrow key pressed")

# pygame捕获键盘事件的两种方式：
# pygame.event.get()方法用于从事件队列中获取所有待处理的事件。这个方法会返回一个事件列表，其中包含所有当前挂起的事件
# pygame.key.get_pressed() 函数返回一个列表，表示键盘上所有按键的状态。列表中每个元素对应一个按键，如果按键被按下，则对应的元素值为 True；
# 如果没有被按下，则为 False。
# 两种方式的比较：方式1的灵活性没有方式2的好，如果对灵活性要求高的游戏，一般建议使用方式2。

# pygame.QUIT:  是一个特定的事件类型, 用户点击了窗口右上角的“X”按钮触发
# pygame.KEYDOWN 是 Pygame 库中用于检测键盘按键按下事件的一个常量
# pygame.K_LEFT: 左箭头键    pygame.K_RIGHT：右箭头键  pygame.K_a: 表示字母"a"键  pygame.K_w: 表示字母"w"键 



# 处理鼠标输入
# 你也可以处理鼠标事件，例如检测鼠标点击：

for event in pygame.event.get():
    if event.type == pygame.QUIT:
        running = False
    elif event.type == pygame.MOUSEBUTTONDOWN:
        print("Mouse button pressed at", event.pos)

# pygame.MOUSEMOTION: 鼠标移动  
# pygame.MOUSEBUTTONDOWN: 鼠标按钮按下 
# pygame.MOUSEBUTTONUP: 鼠标按钮释放

# %%
# 加入了键盘和鼠标事件的完成代码

import pygame

# 初始化 Pygame
pygame.init()

# 设置窗口尺寸
window_size = (480, 640)
screen = pygame.display.set_mode(window_size)

# 设置窗口标题
pygame.display.set_caption("Handle Input")

# 加载图像
player_image = pygame.image.load('resources/car3.png')

# 主循环标志
running = True

# 主循环
while running:
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False
        elif event.type == pygame.KEYDOWN:
            if event.key == pygame.K_LEFT:
                print("Left arrow key pressed")
            elif event.key == pygame.K_RIGHT:
                print("Right arrow key pressed")
        elif event.type == pygame.MOUSEBUTTONDOWN:
            print("Mouse button pressed at", event.pos)

    # 填充背景色
    screen.fill((255, 255, 255))

    # 显示图像
    screen.blit(player_image, (100, 100))

    # 更新屏幕
    pygame.display.flip()

# 退出 Pygame
pygame.quit()

# %%
# 6. 移动图像
# 更新图像位置
# 为了让图像在屏幕上移动，我们需要更新图像的位置。可以使用变量来存储图像的位置，并在主循环中更新这些变量：

player_x = 100
player_y = 100

# 移动图像
player_x += 1

# %%
# 添加了移动图像的完成代码

import pygame

# 初始化 Pygame
pygame.init()

# 设置窗口尺寸
window_size = (480, 640)
screen = pygame.display.set_mode(window_size)

# 设置窗口标题
pygame.display.set_caption("Move Image")

# 加载图像
player_image = pygame.image.load('resources/car3.png')

# 初始化图像位置
player_x = 100
player_y = 100

# 主循环标志
running = True

# 主循环
while running:
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False
        elif event.type == pygame.KEYDOWN:
            if event.key == pygame.K_LEFT:
                player_x -= 5
            elif event.key == pygame.K_RIGHT:
                player_x += 5
            elif event.key == pygame.K_UP:
                player_y -= 5
            elif event.key == pygame.K_DOWN:
                player_y += 5

    # 填充背景色
    screen.fill((255, 255, 255))

    # 显示图像
    screen.blit(player_image, (player_x, player_y))

    # 更新屏幕
    pygame.display.flip()

# 退出 Pygame
pygame.quit()

# %%
# 7. 添加背景音乐和音效

# 初始化混音器
# 在 Pygame 中，可以使用 pygame.mixer 模块来处理声音。首先，需要初始化混音器：
pygame.mixer.init()

# 加载和播放背景音乐
# 可以使用 pygame.mixer.music 模块加载和播放背景音乐：
pygame.mixer.music.load('resources/bgmusic.mp3')
pygame.mixer.music.play(-1)  # -1 表示循环播放

# 加载和播放音效
# 可以使用 pygame.mixer.Sound 类加载和播放音效：
collision_sound = pygame.mixer.Sound('resources/crash.mp3')
collision_sound.play()

# %%
# 加入了背景音乐和音效的完成代码
# 运行这段代码，背景音乐会开始播放，并且按下空格键时会播放音效。

import pygame

# 初始化 Pygame
pygame.init()

# 初始化混音器
pygame.mixer.init()

# 设置窗口尺寸
window_size = (480, 640)
screen = pygame.display.set_mode(window_size)

# 设置窗口标题
pygame.display.set_caption("Music and Sound Effects")

# 加载图像
player_image = pygame.image.load('resources/car3.png')

# 初始化图像位置
player_x = 100
player_y = 100

# 加载背景音乐和音效
pygame.mixer.music.load('resources/bgmusic.mp3')
pygame.mixer.music.play(-1)  # -1 表示循环播放
collision_sound = pygame.mixer.Sound('resources/crash.mp3')

# 主循环标志
running = True

# 主循环
while running:
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False
        elif event.type == pygame.KEYDOWN:
            if event.key == pygame.K_LEFT:
                player_x -= 5
            elif event.key == pygame.K_RIGHT:
                player_x += 5
            elif event.key == pygame.K_UP:
                player_y -= 5
            elif event.key == pygame.K_DOWN:
                player_y += 5
            elif event.key == pygame.K_SPACE:
                collision_sound.play()  # 按下空格键播放音效

    # 填充背景色
    screen.fill((255, 255, 255))

    # 显示图像
    screen.blit(player_image, (player_x, player_y))

    # 更新屏幕
    pygame.display.flip()

# 退出 Pygame
pygame.quit()

# %%
# 8. 处理碰撞检测

# 碰撞检测基础
# Pygame 提供了多种方法来检测对象之间的碰撞。我们可以使用 pygame.Rect 对象来定义矩形区域，并使用 colliderect 方法来检测两个矩形是否碰撞。

# %%
# 加入了碰撞检测的完整代码
# 运行这段代码，你可以使用箭头键移动红色矩形，当红色矩形与蓝色矩形碰撞时，控制台会输出 “Collision detected!”。

import pygame

# 初始化 Pygame
pygame.init()

# 设置窗口尺寸
window_size = (480, 640)
screen = pygame.display.set_mode(window_size)

# 设置窗口标题
pygame.display.set_caption("Collision Detection")

# 定义颜色
WHITE = (255, 255, 255)
RED = (255, 0, 0)
BLUE = (0, 0, 255)

# 初始化矩形位置
rect1 = pygame.Rect(230, 230, 50, 50)
rect2 = pygame.Rect(300, 300, 50, 50)

# 主循环标志
running = True

# 主循环
while running:
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False
        elif event.type == pygame.KEYDOWN:
            if event.key == pygame.K_LEFT:
                rect1.x -= 5
            elif event.key == pygame.K_RIGHT:
                rect1.x += 5
            elif event.key == pygame.K_UP:
                rect1.y -= 5
            elif event.key == pygame.K_DOWN:
                rect1.y += 5

    # 填充背景色
    screen.fill(WHITE)

    # 绘制矩形
    pygame.draw.rect(screen, RED, rect1)
    pygame.draw.rect(screen, BLUE, rect2)

    # 碰撞检测
    if rect1.colliderect(rect2):
        print("Collision detected!")

    # 更新屏幕
    pygame.display.flip()

# 退出 Pygame
pygame.quit()

# %%
# 9. 动画与帧率控制
# 使用 pygame.time.Clock 控制帧率
# 为了控制游戏的帧率，我们可以使用 pygame.time.Clock 对象。它允许我们设置每秒的帧数（FPS），从而控制游戏的速度。

clock = pygame.time.Clock()

# 在主循环的每一帧末尾，调用 clock.tick(fps) 来限制帧率：
clock.tick(60)  # 设置帧率为 60 FPS

# %%
# 加入了控制帧率的完整代码
# 运行这段代码，你会看到一个红色矩形在窗口中移动并反弹。

import pygame

# 初始化 Pygame
pygame.init()

# 设置窗口尺寸
window_size = (480, 640)
screen = pygame.display.set_mode(window_size)

# 设置窗口标题
pygame.display.set_caption("Animation with Frame Rate Control")

# 定义颜色
WHITE = (255, 255, 255)
RED = (255, 0, 0)

# 初始化矩形位置和速度
rect = pygame.Rect(100, 100, 50, 50)
rect_speed = [2, 2]

# 创建时钟对象
clock = pygame.time.Clock()

# 主循环标志
running = True

# 主循环
while running:
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False

    # 移动矩形
    rect.x += rect_speed[0]
    rect.y += rect_speed[1]

    # 碰到边界反弹
    if rect.left < 0 or rect.right > window_size[0]:
        rect_speed[0] = -rect_speed[0]
    if rect.top < 0 or rect.bottom > window_size[1]:
        rect_speed[1] = -rect_speed[1]

    # 填充背景色
    screen.fill(WHITE)

    # 绘制矩形
    pygame.draw.rect(screen, RED, rect)

    # 更新屏幕
    pygame.display.flip()

    # 控制帧率
    clock.tick(60)  # 设置帧率为 60 FPS

# 退出 Pygame
pygame.quit()

# %%
作业：
使用pygame完成疯狂赛车小游戏
1. 获胜逻辑：得分达到10分，画面静止，屏幕显示胜利
2. 失败逻辑：玩家生命值5，生命值为0，则失败，画面静止，屏幕显示失败
3. 添加背景音乐，音效
4. 自由发挥...
